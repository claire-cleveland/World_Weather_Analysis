# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description" : city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | deep river
# Processing Record 3 of Set 1 | cape canaveral
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | kupang
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 1 | nova olinda do norte
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | shalya
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | codrington
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | dhidhdhoo
# Processing Record 24 of Set 1 | puerto escondido
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | les cayes
# Processing Record 27 of Set 1 | bonavista
# Processing Record 28 of Set 1 | lenine
# Processing Record 29 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 1 | ewo
# Processing Record 31 of Set 1 | cascais
# Processing Record 32 of Set 1 | yeppoon
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | klaksvik
# Processing Record 35 of Set 1 | shirokiy
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | lodingen
# Processing Record 38 of Set 1 | contadero
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | aklavik
# Processing Record 41 of Set 1 | esna
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | belmonte
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | terbuny
# Processing Record 50 of Set 1 | antofagasta
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | provideniya
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | vaasa
# Processing Record 5 of Set 2 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 6 of Set 2 | oriximina
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | uglekamensk
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | fairbanks
# Processing Record 11 of Set 2 | nurota
# Processing Record 12 of Set 2 | flin flon
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | nishihara
# Processing Record 19 of Set 2 | tautira
# Processing Record 20 of Set 2 | aktau
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | merauke
# Processing Record 23 of Set 2 | high level
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | mahanoro
# Processing Record 27 of Set 2 | labuhan
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | abu zabad
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | hearst
# Processing Record 36 of Set 2 | zhanaozen
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | palmer
# Processing Record 39 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 2 | coihaique
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | lavrentiya
# Processing Record 43 of Set 2 | mareeba
# Processing Record 44 of Set 2 | mayakonda
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | te anau
# Processing Record 47 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 2 | suao
# City not found. Skipping...
# Processing Record 49 of Set 2 | rockland
# Processing Record 50 of Set 2 | zyryanka
# Processing Record 1 of Set 3 | namibe
# Processing Record 2 of Set 3 | de-kastri
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | tarabuco
# Processing Record 9 of Set 3 | sao raimundo das mangabeiras
# Processing Record 10 of Set 3 | arraial do cabo
# Processing Record 11 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | nantucket
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | muroto
# Processing Record 15 of Set 3 | ancud
# Processing Record 16 of Set 3 | progreso
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | monte alto
# Processing Record 19 of Set 3 | umm lajj
# Processing Record 20 of Set 3 | hay river
# Processing Record 21 of Set 3 | dien bien
# City not found. Skipping...
# Processing Record 22 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 3 | mount isa
# Processing Record 24 of Set 3 | constitucion
# Processing Record 25 of Set 3 | comodoro rivadavia
# Processing Record 26 of Set 3 | vila franca do campo
# Processing Record 27 of Set 3 | arlit
# Processing Record 28 of Set 3 | broome
# Processing Record 29 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 30 of Set 3 | port hueneme
# Processing Record 31 of Set 3 | lima
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | savinskiy
# Processing Record 34 of Set 3 | schwanewede
# Processing Record 35 of Set 3 | codroipo
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | yar-sale
# Processing Record 38 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | laredo
# Processing Record 41 of Set 3 | eureka
# Processing Record 42 of Set 3 | ojinaga
# Processing Record 43 of Set 3 | lorengau
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | canto do buriti
# Processing Record 47 of Set 3 | souillac
# Processing Record 48 of Set 3 | srednekolymsk
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | laguna
# Processing Record 1 of Set 4 | berlevag
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | deputatskiy
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | port macquarie
# Processing Record 8 of Set 4 | yatou
# Processing Record 9 of Set 4 | wah
# Processing Record 10 of Set 4 | sorland
# Processing Record 11 of Set 4 | union
# Processing Record 12 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 4 | anadyr
# Processing Record 14 of Set 4 | santa maria
# Processing Record 15 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 4 | saiha
# Processing Record 17 of Set 4 | providencia
# Processing Record 18 of Set 4 | suslovo
# Processing Record 19 of Set 4 | nazareno
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | walvis bay
# Processing Record 22 of Set 4 | cherskiy
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | kutum
# Processing Record 25 of Set 4 | douglas
# Processing Record 26 of Set 4 | cayenne
# Processing Record 27 of Set 4 | kavaratti
# Processing Record 28 of Set 4 | tankhoy
# Processing Record 29 of Set 4 | sitka
# Processing Record 30 of Set 4 | gornopravdinsk
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | airai
# Processing Record 33 of Set 4 | trairi
# Processing Record 34 of Set 4 | miri
# Processing Record 35 of Set 4 | bambous virieux
# Processing Record 36 of Set 4 | verkhoyansk
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | half moon bay
# Processing Record 39 of Set 4 | bethel
# Processing Record 40 of Set 4 | qaqortoq
# Processing Record 41 of Set 4 | tabuk
# Processing Record 42 of Set 4 | fengxian
# Processing Record 43 of Set 4 | moose factory
# Processing Record 44 of Set 4 | antsohihy
# Processing Record 45 of Set 4 | whitianga
# Processing Record 46 of Set 4 | kovernino
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | waingapu
# Processing Record 49 of Set 4 | eckernforde
# Processing Record 50 of Set 4 | mogadishu
# Processing Record 1 of Set 5 | parabel
# Processing Record 2 of Set 5 | olga
# Processing Record 3 of Set 5 | leshukonskoye
# Processing Record 4 of Set 5 | sungaipenuh
# Processing Record 5 of Set 5 | thunder bay
# Processing Record 6 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 5 | paoua
# Processing Record 8 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 5 | eyl
# Processing Record 10 of Set 5 | tiznit
# Processing Record 11 of Set 5 | kabarnet
# Processing Record 12 of Set 5 | ballina
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | inhambane
# Processing Record 15 of Set 5 | milkovo
# Processing Record 16 of Set 5 | muros
# Processing Record 17 of Set 5 | chara
# Processing Record 18 of Set 5 | vila
# Processing Record 19 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 20 of Set 5 | pousat
# City not found. Skipping...
# Processing Record 21 of Set 5 | bardiyah
# Processing Record 22 of Set 5 | nouadhibou
# Processing Record 23 of Set 5 | cabatuan
# Processing Record 24 of Set 5 | paharpur
# Processing Record 25 of Set 5 | pamanukan
# Processing Record 26 of Set 5 | smithers
# Processing Record 27 of Set 5 | bandarbeyla
# Processing Record 28 of Set 5 | sibolga
# Processing Record 29 of Set 5 | zhigalovo
# Processing Record 30 of Set 5 | filotion
# Processing Record 31 of Set 5 | victoria point
# Processing Record 32 of Set 5 | saint-augustin
# Processing Record 33 of Set 5 | norman wells
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | omsukchan
# Processing Record 36 of Set 5 | copala
# Processing Record 37 of Set 5 | dickinson
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | huntingdon
# Processing Record 40 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 5 | jodhpur
# Processing Record 42 of Set 5 | rairangpur
# Processing Record 43 of Set 5 | mehamn
# Processing Record 44 of Set 5 | daru
# Processing Record 45 of Set 5 | novyy oskol
# Processing Record 46 of Set 5 | ornskoldsvik
# Processing Record 47 of Set 5 | ngunguru
# Processing Record 48 of Set 5 | shitanjing
# Processing Record 49 of Set 5 | barra patuca
# Processing Record 50 of Set 5 | miass
# Processing Record 1 of Set 6 | elblag
# Processing Record 2 of Set 6 | jizan
# Processing Record 3 of Set 6 | vytegra
# Processing Record 4 of Set 6 | katobu
# Processing Record 5 of Set 6 | naberera
# Processing Record 6 of Set 6 | yulara
# Processing Record 7 of Set 6 | vetlanda
# Processing Record 8 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 9 of Set 6 | svetlyy
# Processing Record 10 of Set 6 | lufilufi
# Processing Record 11 of Set 6 | lata
# Processing Record 12 of Set 6 | severo-kurilsk
# Processing Record 13 of Set 6 | yurimaguas
# Processing Record 14 of Set 6 | huarmey
# Processing Record 15 of Set 6 | registro
# Processing Record 16 of Set 6 | chalus
# Processing Record 17 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 6 | portland
# Processing Record 19 of Set 6 | korem
# Processing Record 20 of Set 6 | fort saint james
# Processing Record 21 of Set 6 | veraval
# Processing Record 22 of Set 6 | zaraza
# Processing Record 23 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 6 | haines junction
# Processing Record 25 of Set 6 | taitung
# Processing Record 26 of Set 6 | chunhuhub
# Processing Record 27 of Set 6 | tura
# Processing Record 28 of Set 6 | charagua
# Processing Record 29 of Set 6 | krasnoselkup
# Processing Record 30 of Set 6 | chuy
# Processing Record 31 of Set 6 | chik
# Processing Record 32 of Set 6 | barrow
# Processing Record 33 of Set 6 | lagoa
# Processing Record 34 of Set 6 | flinders
# Processing Record 35 of Set 6 | muramatsu
# Processing Record 36 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 6 | chapais
# Processing Record 38 of Set 6 | neiafu
# Processing Record 39 of Set 6 | mizdah
# Processing Record 40 of Set 6 | karratha
# Processing Record 41 of Set 6 | alice springs
# Processing Record 42 of Set 6 | bagdarin
# Processing Record 43 of Set 6 | manadhoo
# Processing Record 44 of Set 6 | pingyi
# Processing Record 45 of Set 6 | college
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 6 | jiuquan
# Processing Record 49 of Set 6 | san jose
# Processing Record 50 of Set 6 | nogliki
# Processing Record 1 of Set 7 | dunn
# Processing Record 2 of Set 7 | lebu
# Processing Record 3 of Set 7 | caconda
# Processing Record 4 of Set 7 | sibu
# Processing Record 5 of Set 7 | nayudupeta
# Processing Record 6 of Set 7 | cabedelo
# Processing Record 7 of Set 7 | saint anthony
# Processing Record 8 of Set 7 | akyab
# Processing Record 9 of Set 7 | seoul
# Processing Record 10 of Set 7 | olafsvik
# Processing Record 11 of Set 7 | ust-nera
# Processing Record 12 of Set 7 | ntungamo
# Processing Record 13 of Set 7 | hasaki
# Processing Record 14 of Set 7 | sobolevo
# Processing Record 15 of Set 7 | kobelyaky
# Processing Record 16 of Set 7 | dunedin
# Processing Record 17 of Set 7 | martapura
# Processing Record 18 of Set 7 | cody
# Processing Record 19 of Set 7 | gat
# Processing Record 20 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 7 | miraflores
# Processing Record 22 of Set 7 | saint-georges
# Processing Record 23 of Set 7 | masalli
# Processing Record 24 of Set 7 | touros
# Processing Record 25 of Set 7 | alofi
# Processing Record 26 of Set 7 | skjervoy
# Processing Record 27 of Set 7 | port hardy
# Processing Record 28 of Set 7 | satun
# Processing Record 29 of Set 7 | talara
# Processing Record 30 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 7 | darlowo
# Processing Record 32 of Set 7 | rocha
# Processing Record 33 of Set 7 | vao
# Processing Record 34 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 36 of Set 7 | nakamura
# Processing Record 37 of Set 7 | weligama
# Processing Record 38 of Set 7 | aykhal
# Processing Record 39 of Set 7 | westport
# Processing Record 40 of Set 7 | longyearbyen
# Processing Record 41 of Set 7 | rupert
# Processing Record 42 of Set 7 | jinchang
# Processing Record 43 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 7 | asau
# Processing Record 45 of Set 7 | djambala
# Processing Record 46 of Set 7 | sinop
# Processing Record 47 of Set 7 | luderitz
# Processing Record 48 of Set 7 | chipinge
# Processing Record 49 of Set 7 | manali
# Processing Record 50 of Set 7 | sabinas
# Processing Record 1 of Set 8 | kahului
# Processing Record 2 of Set 8 | warrnambool
# Processing Record 3 of Set 8 | saint-pierre
# Processing Record 4 of Set 8 | beipiao
# Processing Record 5 of Set 8 | muroran
# Processing Record 6 of Set 8 | evensk
# Processing Record 7 of Set 8 | luanda
# Processing Record 8 of Set 8 | awjilah
# Processing Record 9 of Set 8 | bambanglipuro
# Processing Record 10 of Set 8 | hailun
# Processing Record 11 of Set 8 | hlobyne
# Processing Record 12 of Set 8 | adrar
# Processing Record 13 of Set 8 | dwarka
# Processing Record 14 of Set 8 | nizwa
# Processing Record 15 of Set 8 | grindavik
# Processing Record 16 of Set 8 | kalmunai
# Processing Record 17 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 8 | acapulco
# Processing Record 19 of Set 8 | bela
# Processing Record 20 of Set 8 | katsuura
# Processing Record 21 of Set 8 | tenenkou
# Processing Record 22 of Set 8 | doaba
# Processing Record 23 of Set 8 | hue
# Processing Record 24 of Set 8 | ayan
# Processing Record 25 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 8 | nikolskoye
# Processing Record 27 of Set 8 | ostrovnoy
# Processing Record 28 of Set 8 | ereymentau
# Processing Record 29 of Set 8 | mikkeli
# Processing Record 30 of Set 8 | huangchuan
# Processing Record 31 of Set 8 | togur
# Processing Record 32 of Set 8 | sampit
# Processing Record 33 of Set 8 | richards bay
# Processing Record 34 of Set 8 | campo grande
# Processing Record 35 of Set 8 | padang
# Processing Record 36 of Set 8 | russell
# Processing Record 37 of Set 8 | paamiut
# Processing Record 38 of Set 8 | soto la marina
# Processing Record 39 of Set 8 | monrovia
# Processing Record 40 of Set 8 | waipawa
# Processing Record 41 of Set 8 | itzehoe
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | nanortalik
# Processing Record 44 of Set 8 | murdochville
# Processing Record 45 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 8 | leningradskiy
# Processing Record 47 of Set 8 | acarau
# Processing Record 48 of Set 8 | toccoa
# Processing Record 49 of Set 8 | iskateley
# Processing Record 50 of Set 8 | athabasca
# Processing Record 1 of Set 9 | sinnamary
# Processing Record 2 of Set 9 | tuatapere
# Processing Record 3 of Set 9 | spornoye
# Processing Record 4 of Set 9 | fort nelson
# Processing Record 5 of Set 9 | bridlington
# Processing Record 6 of Set 9 | san borja
# Processing Record 7 of Set 9 | hinton
# Processing Record 8 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 9 | zambezi
# Processing Record 10 of Set 9 | svetlogorsk
# Processing Record 11 of Set 9 | wahiawa
# Processing Record 12 of Set 9 | samoded
# Processing Record 13 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 9 | kandalaksha
# Processing Record 15 of Set 9 | orebro
# Processing Record 16 of Set 9 | salalah
# Processing Record 17 of Set 9 | ust-kan
# Processing Record 18 of Set 9 | vestmannaeyjar
# Processing Record 19 of Set 9 | port moresby
# Processing Record 20 of Set 9 | lasa
# Processing Record 21 of Set 9 | dali
# Processing Record 22 of Set 9 | xichang
# Processing Record 23 of Set 9 | tsabong
# Processing Record 24 of Set 9 | noumea
# Processing Record 25 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 27 of Set 9 | linfen
# Processing Record 28 of Set 9 | tornio
# Processing Record 29 of Set 9 | champerico
# Processing Record 30 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 31 of Set 9 | peniche
# Processing Record 32 of Set 9 | stepantsevo
# Processing Record 33 of Set 9 | luau
# Processing Record 34 of Set 9 | sarkikaraagac
# Processing Record 35 of Set 9 | kawalu
# Processing Record 36 of Set 9 | bathsheba
# Processing Record 37 of Set 9 | pacific grove
# Processing Record 38 of Set 9 | barra
# Processing Record 39 of Set 9 | zonalnoye
# City not found. Skipping...
# Processing Record 40 of Set 9 | keetmanshoop
# Processing Record 41 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 9 | carutapera
# Processing Record 43 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 44 of Set 9 | ellisras
# Processing Record 45 of Set 9 | nawa
# Processing Record 46 of Set 9 | novoorsk
# Processing Record 47 of Set 9 | mahoba
# Processing Record 48 of Set 9 | komsomolskiy
# Processing Record 49 of Set 9 | kerema
# Processing Record 50 of Set 9 | vestmanna
# Processing Record 1 of Set 10 | eaglesfield
# Processing Record 2 of Set 10 | nandura
# Processing Record 3 of Set 10 | tateyama
# Processing Record 4 of Set 10 | naenwa
# City not found. Skipping...
# Processing Record 5 of Set 10 | pouembout
# Processing Record 6 of Set 10 | vostok
# Processing Record 7 of Set 10 | tual
# Processing Record 8 of Set 10 | bara
# Processing Record 9 of Set 10 | zaykovo
# Processing Record 10 of Set 10 | terrace bay
# Processing Record 11 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 13 of Set 10 | norilsk
# Processing Record 14 of Set 10 | guiyang
# Processing Record 15 of Set 10 | isangel
# Processing Record 16 of Set 10 | bonnyville
# Processing Record 17 of Set 10 | emba
# Processing Record 18 of Set 10 | gwadar
# Processing Record 19 of Set 10 | buala
# Processing Record 20 of Set 10 | wucheng
# Processing Record 21 of Set 10 | wenling
# Processing Record 22 of Set 10 | egvekinot
# Processing Record 23 of Set 10 | erenhot
# Processing Record 24 of Set 10 | zakamensk
# Processing Record 25 of Set 10 | kichera
# Processing Record 26 of Set 10 | burgeo
# Processing Record 27 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 10 | jacareacanga
# Processing Record 29 of Set 10 | hambantota
# Processing Record 30 of Set 10 | joshimath
# Processing Record 31 of Set 10 | praia da vitoria
# Processing Record 32 of Set 10 | bougouni
# Processing Record 33 of Set 10 | koronowo
# Processing Record 34 of Set 10 | kholodnyy
# Processing Record 35 of Set 10 | maunabo
# Processing Record 36 of Set 10 | gwembe
# Processing Record 37 of Set 10 | kholtoson
# Processing Record 38 of Set 10 | caravelas
# Processing Record 39 of Set 10 | shancheng
# Processing Record 40 of Set 10 | lang son
# Processing Record 41 of Set 10 | kijang
# Processing Record 42 of Set 10 | la ronge
# Processing Record 43 of Set 10 | ixtapa
# Processing Record 44 of Set 10 | kashi
# Processing Record 45 of Set 10 | taltal
# Processing Record 46 of Set 10 | ozinki
# Processing Record 47 of Set 10 | juneau
# Processing Record 48 of Set 10 | butajira
# Processing Record 49 of Set 10 | plettenberg bay
# Processing Record 50 of Set 10 | celestun
# Processing Record 1 of Set 11 | sao joao da barra
# Processing Record 2 of Set 11 | moose jaw
# Processing Record 3 of Set 11 | cap malheureux
# Processing Record 4 of Set 11 | ust-barguzin
# Processing Record 5 of Set 11 | san andres
# Processing Record 6 of Set 11 | kieta
# Processing Record 7 of Set 11 | kayerkan
# Processing Record 8 of Set 11 | goderich
# Processing Record 9 of Set 11 | oussouye
# Processing Record 10 of Set 11 | neuquen
# Processing Record 11 of Set 11 | chebenki
# Processing Record 12 of Set 11 | salgar
# Processing Record 13 of Set 11 | darhan
# Processing Record 14 of Set 11 | duz
# City not found. Skipping...
# Processing Record 15 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 11 | raudeberg
# Processing Record 17 of Set 11 | bhanjanagar
# Processing Record 18 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 19 of Set 11 | amurzet
# Processing Record 20 of Set 11 | vardo
# Processing Record 21 of Set 11 | det udom
# Processing Record 22 of Set 11 | namatanai
# Processing Record 23 of Set 11 | sadat
# Processing Record 24 of Set 11 | azul
# Processing Record 25 of Set 11 | chaman
# Processing Record 26 of Set 11 | banda aceh
# Processing Record 27 of Set 11 | clyde river
# Processing Record 28 of Set 11 | port blair
# Processing Record 29 of Set 11 | muravlenko
# Processing Record 30 of Set 11 | ilulissat
# Processing Record 31 of Set 11 | ambon
# Processing Record 32 of Set 11 | bilibino
# Processing Record 33 of Set 11 | north platte
# Processing Record 34 of Set 11 | redlands
# Processing Record 35 of Set 11 | grivenskaya
# Processing Record 36 of Set 11 | iracoubo
# Processing Record 37 of Set 11 | calafell
# Processing Record 38 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 11 | salym
# Processing Record 40 of Set 11 | port alberni
# Processing Record 41 of Set 11 | svetlaya
# Processing Record 42 of Set 11 | pehowa
# Processing Record 43 of Set 11 | azoyu
# Processing Record 44 of Set 11 | viedma
# Processing Record 45 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 11 | luganville
# Processing Record 47 of Set 11 | whitehorse
# Processing Record 48 of Set 11 | kristiansund
# Processing Record 49 of Set 11 | bull savanna
# Processing Record 50 of Set 11 | hokitika
# Processing Record 1 of Set 12 | morgan city
# Processing Record 2 of Set 12 | maniitsoq
# Processing Record 3 of Set 12 | taoudenni
# Processing Record 4 of Set 12 | port hedland
# Processing Record 5 of Set 12 | adeje
# Processing Record 6 of Set 12 | preobrazheniye
# Processing Record 7 of Set 12 | am timan
# Processing Record 8 of Set 12 | ocean city
# Processing Record 9 of Set 12 | farafangana
# Processing Record 10 of Set 12 | caramay
# Processing Record 11 of Set 12 | massaguet
# Processing Record 12 of Set 12 | waddan
# Processing Record 13 of Set 12 | sabinas hidalgo
# Processing Record 14 of Set 12 | henties bay
# Processing Record 15 of Set 12 | krasnoyarskiy
# Processing Record 16 of Set 12 | oktyabrskoye
# Processing Record 17 of Set 12 | khilok
# Processing Record 18 of Set 12 | ekhabi
# Processing Record 19 of Set 12 | diffa
# Processing Record 20 of Set 12 | puerto palomas
# Processing Record 21 of Set 12 | zavallya
# Processing Record 22 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 23 of Set 12 | barranco
# Processing Record 24 of Set 12 | fukuma
# Processing Record 25 of Set 12 | chumikan
# Processing Record 26 of Set 12 | maceio
# Processing Record 27 of Set 12 | sesheke
# Processing Record 28 of Set 12 | nenjiang
# Processing Record 29 of Set 12 | okha
# Processing Record 30 of Set 12 | bol
# Processing Record 31 of Set 12 | tadine
# Processing Record 32 of Set 12 | mnogovershinnyy
# Processing Record 33 of Set 12 | mende
# Processing Record 34 of Set 12 | nuuk
# Processing Record 35 of Set 12 | klishkivtsi
# Processing Record 36 of Set 12 | dicabisagan
# Processing Record 37 of Set 12 | blagoyevo
# Processing Record 38 of Set 12 | imbituba
# Processing Record 39 of Set 12 | axim
# Processing Record 40 of Set 12 | shamilkala
# Processing Record 41 of Set 12 | gobabis
# Processing Record 42 of Set 12 | sangar
# Processing Record 43 of Set 12 | korla
# Processing Record 44 of Set 12 | bandiagara
# Processing Record 45 of Set 12 | wum
# Processing Record 46 of Set 12 | baldeogarh
# Processing Record 47 of Set 12 | marsh harbour
# Processing Record 48 of Set 12 | tigil
# Processing Record 49 of Set 12 | north bend
# Processing Record 50 of Set 12 | bom jesus
# Processing Record 1 of Set 13 | gandajika
# Processing Record 2 of Set 13 | zelenogradsk
# Processing Record 3 of Set 13 | kavieng
# Processing Record 4 of Set 13 | nyurba
# Processing Record 5 of Set 13 | yaan
# Processing Record 6 of Set 13 | tambovka
# Processing Record 7 of Set 13 | san cristobal
# Processing Record 8 of Set 13 | batemans bay
# Processing Record 9 of Set 13 | nome
# Processing Record 10 of Set 13 | marawi
# Processing Record 11 of Set 13 | charters towers
# Processing Record 12 of Set 13 | khani
# Processing Record 13 of Set 13 | nelson bay
# Processing Record 14 of Set 13 | geraldton
# Processing Record 15 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 13 | wewak
# Processing Record 17 of Set 13 | hirara
# Processing Record 18 of Set 13 | lodja
# Processing Record 19 of Set 13 | roswell
# Processing Record 20 of Set 13 | ust-omchug
# Processing Record 21 of Set 13 | alta gracia
# Processing Record 22 of Set 13 | auch
# Processing Record 23 of Set 13 | narasannapeta
# Processing Record 24 of Set 13 | heishan
# Processing Record 25 of Set 13 | sao felix do xingu
# Processing Record 26 of Set 13 | zwedru
# Processing Record 27 of Set 13 | yarensk
# Processing Record 28 of Set 13 | coquimbo
# Processing Record 29 of Set 13 | shelburne
# Processing Record 30 of Set 13 | phan thiet
# Processing Record 31 of Set 13 | billings
# Processing Record 32 of Set 13 | chengdu
# Processing Record 33 of Set 13 | hervey bay
# Processing Record 34 of Set 13 | yagodnoye
# Processing Record 35 of Set 13 | desaguadero
# Processing Record 36 of Set 13 | mandera
# Processing Record 37 of Set 13 | chontalpa
# Processing Record 38 of Set 13 | minab
# Processing Record 39 of Set 13 | samarai
# Processing Record 40 of Set 13 | kalabo
# Processing Record 41 of Set 13 | abakaliki
# Processing Record 42 of Set 13 | ulladulla
# Processing Record 43 of Set 13 | carauari
# Processing Record 44 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 45 of Set 13 | brae
# Processing Record 46 of Set 13 | oranjemund
# Processing Record 47 of Set 13 | alta floresta
# Processing Record 48 of Set 13 | shubarkuduk
# Processing Record 49 of Set 13 | margate
# Processing Record 50 of Set 13 | pingxiang
# Processing Record 1 of Set 14 | solwezi
# Processing Record 2 of Set 14 | ternate
# Processing Record 3 of Set 14 | odweyne
# Processing Record 4 of Set 14 | mamallapuram
# Processing Record 5 of Set 14 | reconquista
# Processing Record 6 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 14 | mayo
# Processing Record 8 of Set 14 | platanos
# Processing Record 9 of Set 14 | sao borja
# Processing Record 10 of Set 14 | jati
# Processing Record 11 of Set 14 | lagunas
# Processing Record 12 of Set 14 | camacha
# Processing Record 13 of Set 14 | dingle
# Processing Record 14 of Set 14 | owando
# Processing Record 15 of Set 14 | marfino
# Processing Record 16 of Set 14 | hastings
# Processing Record 17 of Set 14 | payo
# Processing Record 18 of Set 14 | paka
# Processing Record 19 of Set 14 | meulaboh
# Processing Record 20 of Set 14 | robat karim
# Processing Record 21 of Set 14 | santa vitoria do palmar
# Processing Record 22 of Set 14 | narsaq
# Processing Record 23 of Set 14 | winslow
# Processing Record 24 of Set 14 | saint-joseph
# Processing Record 25 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 26 of Set 14 | cacahuatepec
# Processing Record 27 of Set 14 | olot
# Processing Record 28 of Set 14 | luwuk
# Processing Record 29 of Set 14 | diamantino
# Processing Record 30 of Set 14 | fuerte olimpo
# Processing Record 31 of Set 14 | tokuyama
# Processing Record 32 of Set 14 | santa luzia
# Processing Record 33 of Set 14 | orlik
# Processing Record 34 of Set 14 | hartlepool
# Processing Record 35 of Set 14 | kohlu
# Processing Record 36 of Set 14 | salinas
# Processing Record 37 of Set 14 | januaria
# Processing Record 38 of Set 14 | vyartsilya
# Processing Record 39 of Set 14 | jibuti
# Processing Record 40 of Set 14 | grand forks
# Processing Record 41 of Set 14 | galesong
# Processing Record 42 of Set 14 | masumbwe
# Processing Record 43 of Set 14 | ikalamavony
# Processing Record 44 of Set 14 | gaspar
# Processing Record 45 of Set 14 | guhagar
# Processing Record 46 of Set 14 | naron
# Processing Record 47 of Set 14 | miles city
# Processing Record 48 of Set 14 | beloha
# Processing Record 49 of Set 14 | san vicente
# Processing Record 50 of Set 14 | kaspiyskiy
# Processing Record 1 of Set 15 | nyakahanga
# Processing Record 2 of Set 15 | dolinsk
# Processing Record 3 of Set 15 | amalapuram
# Processing Record 4 of Set 15 | volsk
# Processing Record 5 of Set 15 | itaituba
# Processing Record 6 of Set 15 | kanniyakumari
# Processing Record 7 of Set 15 | zilair
# Processing Record 8 of Set 15 | kanker
# Processing Record 9 of Set 15 | wanning
# Processing Record 10 of Set 15 | faya
# Processing Record 11 of Set 15 | lethem
# Processing Record 12 of Set 15 | shingu
# Processing Record 13 of Set 15 | sosnovka
# Processing Record 14 of Set 15 | shagonar
# Processing Record 15 of Set 15 | baymak
# Processing Record 16 of Set 15 | bilma
# Processing Record 17 of Set 15 | xining
# Processing Record 18 of Set 15 | catamarca
# Processing Record 19 of Set 15 | linqiong
# Processing Record 20 of Set 15 | puerto colombia
# Processing Record 21 of Set 15 | hamilton
# Processing Record 22 of Set 15 | roanoke
# Processing Record 23 of Set 15 | saurimo
# Processing Record 24 of Set 15 | slatina
# Processing Record 25 of Set 15 | hala
# Processing Record 26 of Set 15 | honiara
# Processing Record 27 of Set 15 | manfredonia
# Processing Record 28 of Set 15 | mlowo
# Processing Record 29 of Set 15 | abu samrah
# Processing Record 30 of Set 15 | puerto baquerizo moreno
# Processing Record 31 of Set 15 | harper
# Processing Record 32 of Set 15 | micheweni
# Processing Record 33 of Set 15 | goshogawara
# Processing Record 34 of Set 15 | inyonga
# Processing Record 35 of Set 15 | udachnyy
# Processing Record 36 of Set 15 | pierre
# Processing Record 37 of Set 15 | safaga
# Processing Record 38 of Set 15 | ahipara
# Processing Record 39 of Set 15 | kyra
# Processing Record 40 of Set 15 | itarema
# Processing Record 41 of Set 15 | lianzhou
# Processing Record 42 of Set 15 | ucluelet
# Processing Record 43 of Set 15 | kalevala
# Processing Record 44 of Set 15 | mentougou
# Processing Record 45 of Set 15 | podstepki
# Processing Record 46 of Set 15 | dongsheng
# Processing Record 47 of Set 15 | marondera
# Processing Record 48 of Set 15 | tawang
# Processing Record 49 of Set 15 | biggar
# Processing Record 50 of Set 15 | kilis
# Processing Record 1 of Set 16 | liwale
# Processing Record 2 of Set 16 | horta
# Processing Record 3 of Set 16 | quthing
# Processing Record 4 of Set 16 | kloulklubed
# Processing Record 5 of Set 16 | varhaug
# Processing Record 6 of Set 16 | leh
# Processing Record 7 of Set 16 | lavumisa
# Processing Record 8 of Set 16 | cao bang
# Processing Record 9 of Set 16 | tashla
# Processing Record 10 of Set 16 | matara
# Processing Record 11 of Set 16 | bud
# Processing Record 12 of Set 16 | paracuru
# Processing Record 13 of Set 16 | kushiro
# Processing Record 14 of Set 16 | lagdo
# Processing Record 15 of Set 16 | kangaatsiaq
# Processing Record 16 of Set 16 | afyonkarahisar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo  19.7297 -155.0900     82.13        74          75
# 1      Deep River  46.1001  -77.4995     64.15        99          86
# 2  Cape Canaveral  28.4058  -80.6048     77.99        93           1
# 3          Albany  42.6001  -73.9662     68.76        94          92
# 4      Georgetown   5.4112  100.3354     82.35        77          20
# 5           Bluff -46.6000  168.3333     49.80        74         100
# 6    Punta Arenas -53.1500  -70.9167     37.51        87           0
# 7  Saint-Philippe -21.3585   55.7679     67.59        84          96
# 8        Thompson  55.7435  -97.8558     71.76        53          75
# 9         Rikitea -23.1203 -134.9692     71.64        76           2
#
#    Wind Speed Country                 Date Current Description
# 0        9.22      US  2021-07-30 02:23:25       broken clouds
# 1        4.81      CA  2021-07-30 02:24:10     overcast clouds
# 2        4.61      US  2021-07-30 02:24:10           clear sky
# 3        4.68      US  2021-07-30 02:24:10     overcast clouds
# 4        4.61      MY  2021-07-30 02:21:05          few clouds
# 5        3.71      NZ  2021-07-30 02:24:11     overcast clouds
# 6       18.41      CL  2021-07-30 02:22:19           clear sky
# 7       15.59      RE  2021-07-30 02:24:12          light rain
# 8        4.61      CA  2021-07-30 02:17:05       broken clouds
# 9        3.53      PF  2021-07-30 02:18:47           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
